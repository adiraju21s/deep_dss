# %%
from deep_dss.utils import split_poisson_maps_by_datasets

# %%
data = split_poisson_maps_by_datasets(density=1000)
# Out:
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.6/site-packages/healpy/fitsfunc.py:352: UserWarning: If you are not specifying the input dtype and using the default np.float64 dtype of read_map(), please consider that it will change in a future version to None as to keep the same dtype of the input file: please explicitly set the dtype if it is important to you.
#   "If you are not specifying the input dtype and using the default "
# NSIDE = 1024
# ORDERING = NESTED in fits file
# INDXSCHM = IMPLICIT
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.6/site-packages/healpy/fitsfunc.py:352: UserWarning: If you are not specifying the input dtype and using the default np.float64 dtype of read_map(), please consider that it will change in a future version to None as to keep the same dtype of the input file: please explicitly set the dtype if it is important to you.
#   "If you are not specifying the input dtype and using the default "
# NSIDE = 1024
# ...

# %%
data["Q1"]["x"]
# Out:
# array([[[0.58774356],
#         [0.69515514],
#         [0.26555259],
#         ...,
#         [0.55977453],
#         [0.30809703],
#         [0.24537462]],
#
#        [[0.3904284 ],
#         [0.25946856],
#         [0.48182016],
#         ...,
#         [0.87054153],
#         [0.54646845],
#         [0.44264601]],
#
#        [[1.49133144],
#         [0.74470278],
#         [0.55793619],
#         ...,
#         [0.60700236],
#         [0.26905419],
#         [0.32971941]],
#
#        ...,
#
#        [[0.43095942],
#         [0.35046639],
#         [0.23806503],
#         ...,
#         [0.89697861],
#         [0.42842076],
#         [0.44452812]],
#
#        [[0.24804459],
#         [0.30411396],
#         [0.47639268],
#         ...,
#         [0.71975388],
#         [0.37913574],
#         [0.55929306]],
#
#        [[1.49045604],
#         [1.07297778],
#         [1.52026341],
#         ...,
#         [0.58971321],
#         [0.50112273],
#         [0.6364158 ]]])

# %%
partial = data["Q1"]["x"][0]

# %%
partial.shape
# Out:
# (262144, 1)

# %%
from deep_dss.utils import set_constants

# %%
(NSIDE, NPIX, PIXEL_AREA, ORDER, BIAS, DENSITY_M, DENSITY_KG, ELLIP_SIGMA) = set_constants()

# %%
import healpy as hp
from deep_dss.utils import *

# %%
hp.mollview(poisson_map_by_val(0.85, density=1000), nest=True)
# Out:
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.6/site-packages/healpy/fitsfunc.py:352: UserWarning: If you are not specifying the input dtype and using the default np.float64 dtype of read_map(), please consider that it will change in a future version to None as to keep the same dtype of the input file: please explicitly set the dtype if it is important to you.
#   "If you are not specifying the input dtype and using the default "
# NSIDE = 1024
# ORDERING = NESTED in fits file
# INDXSCHM = IMPLICIT

# %%
import matplotlib.pyplot as plt

# %%
thinmap = poisson_map_by_val(0.85, density=1000)
thickmap = poisson_map_by_val(0.85)
# Out:
# NSIDE = 1024
# ORDERING = NESTED in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 1024
# ORDERING = NESTED in fits file
# INDXSCHM = IMPLICIT

# %%
thinmap
# Out:
# array([0.58910043, 0.67751583, 0.30393888, ..., 0.58691193, 0.52007514,
#        0.64136181])

# %%
thickmap
# Out:
# array([0., 0., 0., ..., 1., 2., 0.])

# %%
plt.hist(200*thinmap, bins=20000)
plt.show()

# %%
plt.hist(200*thickmap)
plt.show()

# %%
hp.mollview(poisson_map_by_val(0.85), nest=True)
# Out:
# NSIDE = 1024
# ORDERING = NESTED in fits file
# INDXSCHM = IMPLICIT

# %%
from deep_dss.utils import *
