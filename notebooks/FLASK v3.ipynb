# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import healpy as hp
import matplotlib.pyplot as plt

from deep_dss.helpers import *

# %%
counts = count_map_by_val(0.5, gaussian=True)
# Out:
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:368: UserWarning: If you are not specifying the input dtype and using the default np.float64 dtype of read_map(), please consider that it will change in a future version to None as to keep the same dtype of the input file: please explicitly set the dtype if it is important to you.
#   warnings.warn(
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:391: UserWarning: NSIDE = 1024
#   warnings.warn("NSIDE = {0:d}".format(nside))
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:400: UserWarning: ORDERING = NESTED in fits file
#   warnings.warn("ORDERING = {0:s} in fits file".format(ordering))
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:428: UserWarning: INDXSCHM = IMPLICIT
#   warnings.warn("INDXSCHM = {0:s}".format(schm))

# %%
hp.mollzoom(counts, nest=True)
# Out:
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/projaxes.py:920: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("viridis"))
#   newcm.set_over(newcm(1.0))
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/projaxes.py:921: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("viridis"))
#   newcm.set_under(bgcolor)
# ...

# %%
counts_log = count_map_by_val(0.5)
# Out:
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:368: UserWarning: If you are not specifying the input dtype and using the default np.float64 dtype of read_map(), please consider that it will change in a future version to None as to keep the same dtype of the input file: please explicitly set the dtype if it is important to you.
#   warnings.warn(
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:391: UserWarning: NSIDE = 1024
#   warnings.warn("NSIDE = {0:d}".format(nside))
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:400: UserWarning: ORDERING = NESTED in fits file
#   warnings.warn("ORDERING = {0:s} in fits file".format(ordering))
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:428: UserWarning: INDXSCHM = IMPLICIT
#   warnings.warn("INDXSCHM = {0:s}".format(schm))

# %%
hp.mollzoom(counts_log, nest=True)

# %%
split_maps = split_count_maps_by_val(0.5, gaussian=True, mixed_bias=True, rand_bias=True)
# Out:
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:368: UserWarning: If you are not specifying the input dtype and using the default np.float64 dtype of read_map(), please consider that it will change in a future version to None as to keep the same dtype of the input file: please explicitly set the dtype if it is important to you.
#   warnings.warn(
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:391: UserWarning: NSIDE = 1024
#   warnings.warn("NSIDE = {0:d}".format(nside))
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:400: UserWarning: ORDERING = NESTED in fits file
#   warnings.warn("ORDERING = {0:s} in fits file".format(ordering))
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:428: UserWarning: INDXSCHM = IMPLICIT
#   warnings.warn("INDXSCHM = {0:s}".format(schm))
# (48, 262144)
# (262144,)
# 0

# %%
p = split_map(load_map_by_val(0.85, gaussian=True))

# %%
p
# Out:
# array([[-0.15780738, -0.29777592,  0.23398501, ..., -0.68472934,
#         -0.39249817, -0.45981613],
#        [ 0.0433036 , -0.07887779,  0.20322974, ..., -0.01776282,
#         -0.06739766, -0.51735801],
#        [-0.42961454,  0.41083634,  0.08285776, ...,  0.11436001,
#          0.36656058,  0.49577031],
#        ...,
#        [-0.20667788,  0.11187385, -0.56019092, ...,  0.14312111,
#          0.10173739, -0.0581462 ],
#        [-0.40019259, -0.02306843, -0.04873221, ...,  0.25127271,
#          0.3436338 ,  0.0247864 ],
#        [ 0.51825798,  0.43429744,  0.16417776, ...,  0.47995216,
#         -0.1085245 ,  0.20963956]])

# %%
p.shape
# Out:
# (48, 262144)

# %%
p[0] = accelerated_noiseless_counts(p[0], rand_bias=True)

# %%
p
# Out:
# array([[ 0.43507532,  0.3627678 ,  0.63747462, ...,  0.1628683 ,
#          0.31383445,  0.2790581 ],
#        [ 0.0433036 , -0.07887779,  0.20322974, ..., -0.01776282,
#         -0.06739766, -0.51735801],
#        [-0.42961454,  0.41083634,  0.08285776, ...,  0.11436001,
#          0.36656058,  0.49577031],
#        ...,
#        [-0.20667788,  0.11187385, -0.56019092, ...,  0.14312111,
#          0.10173739, -0.0581462 ],
#        [-0.40019259, -0.02306843, -0.04873221, ...,  0.25127271,
#          0.3436338 ,  0.0247864 ],
#        [ 0.51825798,  0.43429744,  0.16417776, ...,  0.47995216,
#         -0.1085245 ,  0.20963956]])

# %%
12 * 2 ** 2
# Out:
# 48

# %%
for i in range(48):
    p[i] = accelerated_noiseless_counts(p[i], rand_bias=True)

# %%
p
# Out:
# array([[0.43507532, 0.3627678 , 0.63747462, ..., 0.1628683 , 0.31383445,
#         0.2790581 ],
#        [0.53896892, 0.47585022, 0.6215865 , ..., 0.50742211, 0.48178083,
#         0.24933206],
#        [0.29466019, 0.72883573, 0.55940253, ..., 0.57567655, 0.70596294,
#         0.77271248],
#        ...,
#        [0.4098289 , 0.5743922 , 0.22720465, ..., 0.59053448, 0.56915572,
#         0.48656012],
#        [0.30985952, 0.50468124, 0.49142337, ..., 0.64640542, 0.69411901,
#         0.52940296],
#        [0.78432957, 0.7409557 , 0.60141231, ..., 0.76454085, 0.46053477,
#         0.62489781]])

# %%
p = split_count_maps_by_val(0.5, rand_bias=True, mixed_bias=True)
# Out:
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:368: UserWarning: If you are not specifying the input dtype and using the default np.float64 dtype of read_map(), please consider that it will change in a future version to None as to keep the same dtype of the input file: please explicitly set the dtype if it is important to you.
#   warnings.warn(
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:391: UserWarning: NSIDE = 1024
#   warnings.warn("NSIDE = {0:d}".format(nside))
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:400: UserWarning: ORDERING = NESTED in fits file
#   warnings.warn("ORDERING = {0:s} in fits file".format(ordering))
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:428: UserWarning: INDXSCHM = IMPLICIT
#   warnings.warn("INDXSCHM = {0:s}".format(schm))
# (48, 262144)
# (262144,)
# 0
# 1
# 2
# 3
# ...

# %%
def plot_random_map(sigma8, gaussian=False, noiseless=False, rand_bias=False, mixed_bias=False, bias=1.54):
    m = count_map_by_val(sigma8, gaussian=gaussian, noiseless=noiseless, rand_bias=rand_bias,
                        bias=bias)
    print("Zero density fraction: ", np.count_nonzero(m)/m.size)
    hp.mollzoom(m, nest=True)

# %%
plot_random_map(0.85)
# Out:
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:368: UserWarning: If you are not specifying the input dtype and using the default np.float64 dtype of read_map(), please consider that it will change in a future version to None as to keep the same dtype of the input file: please explicitly set the dtype if it is important to you.
#   warnings.warn(
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:391: UserWarning: NSIDE = 1024
#   warnings.warn("NSIDE = {0:d}".format(nside))
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:400: UserWarning: ORDERING = NESTED in fits file
#   warnings.warn("ORDERING = {0:s} in fits file".format(ordering))
# /Users/adiraju/opt/anaconda3/envs/deep_dss/lib/python3.8/site-packages/healpy/fitsfunc.py:428: UserWarning: INDXSCHM = IMPLICIT
#   warnings.warn("INDXSCHM = {0:s}".format(schm))
# Zero density fraction:  0.3919827143351237
# ...

# %%
plot_random_map(0.85, gaussian=True)
# Out:
# Zero density fraction:  0.3912041982014974

# %%
for i in range(20):
    plot_random_map(0.85, rand_bias=True)
# Out:
# Zero density fraction:  0.39187200864156085
# Zero density fraction:  0.39212481180826825
# Zero density fraction:  0.391800324122111
# Zero density fraction:  0.39203675587972003
# Zero density fraction:  0.39190061887105304
# Zero density fraction:  0.3918497562408447
# Zero density fraction:  0.3919824759165446
# Zero density fraction:  0.3919841448465983
# Zero density fraction:  0.3921538194020589
# Zero density fraction:  0.3920227686564128
# Zero density fraction:  0.39182289441426593
# Zero density fraction:  0.39180469512939453
# Zero density fraction:  0.3921012083689372
# Zero density fraction:  0.3919531504313151
# Zero density fraction:  0.3920617898305257
# Zero density fraction:  0.39165544509887695
# Zero density fraction:  0.3916656970977783
# Zero density fraction:  0.3919193744659424
# Zero density fraction:  0.3919665813446045
# Zero density fraction:  0.3918325901031494

# %%
maps = split_count_maps_by_val(0.85, mixed_bias=True, rand_bias=True)

# %%
np.random.uniform(0.8, 3.0)
# Out:
# 1.1321491581177008
